# %% [markdown]
# <a href="https://colab.research.google.com/github/rahiakela/modern-computer-vision-with-pytorch/blob/main/7-basics-of-object-detection/3_training_fast_r_cnn_based_custom_object_detectors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training Fast R-CNN-based custom object detectors

# %% [markdown]
# One of the major drawbacks of R-CNN is that it takes considerable time to generate predictions, as generating region proposals for each image, resizing the crops of regions, and extracting features corresponding to each crop (region proposal), constitute the bottleneck.
#
# Fast R-CNN gets around this problem by passing the entire image through the
# pretrained model to extract features and then fetching the region of features that correspond to the region proposals (which are obtained from selectivesearch) of the original image.
#
# In this notebook, we will learn about the working details of R-CNN before training it on our custom dataset.

# %% [markdown]
# ## Setup

# %%
# !pip install -q --upgrade selectivesearch torch_snippets
# Out:
#      |████████████████████████████████| 61kB 9.5MB/s
#      |████████████████████████████████| 102kB 12.2MB/s
#   Building wheel for selectivesearch (setup.py) ... done
#   Building wheel for contextvars (setup.py) ... done

# %%
from torch_snippets import *
import selectivesearch

# %%
from torchvision import transforms, models, datasets
from torch_snippets import Report
from torchvision.ops import nms
from torchvision.ops import RoIPool

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from torchvision.ops import nms
from PIL import Image

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %matplotlib inline

# %% [markdown]
# ## Working details of Fast R-CNN

# %% [markdown]
# Let's understand Fast R-CNN through the following diagram:
#
# <img src='https://github.com/rahiakela/img-repo/blob/master/object-detection-images/fast-r-cnn.png?raw=1' width='800'/>
#
# We perform the following steps when leveraging the Fast R-CNN technique for object detection:
#
# 1. Pass the image through a pretrained model to extract features prior to the
# flattening layer; let's call the output as feature maps.
# 2. Extract region proposals corresponding to the image.
# 3. Extract the feature map area corresponding to the region proposals (note
# that when an image is passed through a VGG16 architecture, the image is
# downscaled by 32 at the output as there are 5 pooling operations
# performed. Thus, if a region exists with a bounding box of (40,32,200,240)
# in the original image, the feature map corresponding to the bounding box
# of (5,4,25,30) would correspond to the exact same region).
# 4. Pass the feature maps corresponding to region proposals through the RoI
# (Region of Interest) pooling layer one at a time so that all feature maps of
# region proposals have a similar shape. This is a replacement for the
# warping that was executed in the R-CNN technique.
# 5. Pass the RoI pooling layer output value through a fully connected layer.
# 6. Train the model to predict the class and offsets corresponding to each
# region proposal.
#
# >>Note that the big difference between R-CNN and Fast R-CNN is
# that, in R-CNN, we are passing the crops (resized region proposals)
# through the pretrained model one at a time, while in Fast R-CNN,
# we are cropping the feature map (which is obtained by passing the
# whole image through a pretrained model) corresponding to each
# region proposal and thereby avoiding the need to pass each resized
# region proposal through the pretrained model.

# %% [markdown]
# ## Implementing Fast R-CNN for object detection on a custom dataset

# %% [markdown]
# In this section, we will work toward training our custom object detector using Fast RCNN. Furthermore, so as to remain succinct, we provide only the additional or the changed code in this section.

# %% [markdown]
# ## Downloading the dataset

# %% [markdown]
# For the scenario of object detection, we will download the data from Kaggle that is the Google Open Images v6 dataset.
#
# However, we will work on only those images that are of a bus or a truck to ensure that we can train images (as you will shortly notice the memory issues associated with using selectivesearch).

# %%
from google.colab import files
files.upload() # upload kaggle.json file
# Out:
#      <input type="file" id="files-bb713e99-7cb5-4890-8a74-e6c8abd9e3b9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb713e99-7cb5-4890-8a74-e6c8abd9e3b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"rahiakela","key":"484f91b2ebc194b0bff8ab8777c1ebff"}'}

# %%
# %%shell
#
# mkdir -p ~/.kaggle
# mv kaggle.json ~/.kaggle/
# ls ~/.kaggle
# chmod 600 /root/.kaggle/kaggle.json
#
# # download dataset from kaggle
# kaggle datasets download -d sixhky/open-images-bus-trucks/
# unzip -qq open-images-bus-trucks.zip
# Out:
# kaggle.json
# Downloading open-images-bus-trucks.zip to /content
#  94% 345M/367M [00:03<00:00, 82.9MB/s]
# 100% 367M/367M [00:03<00:00, 108MB/s]

# %% [markdown]
# ## Preparing the dataset

# %% [markdown]
# Now that we have downloaded the dataset, we will prepare the dataset. This involves the following steps:
#
# 1. Fetching each image and its corresponding class and bounding box values
# 2. Fetching the region proposals within each image, their corresponding IoU, and the delta by which the region proposal is to be corrected with respect to the ground truth
# 3. Assigning numeric labels for each class (where we have an additional background class (besides the bus and truck classes) where IoU with the ground truth bounding box is below a threshold)
# 4. Resizing each region proposal to a common size in order to pass them to a network
#
# By the end of this exercise, we will have resized crops of region proposals, along with assigning the ground truth class to each region proposal, and calculated the offset of the region proposal in relation to the ground truth bounding box.
#
# Specify the location of images and read the ground truths present in the CSV file that we downloaded:

# %%
IMAGE_ROOT = "images/images/"
DF_RAW = pd.read_csv("df.csv")
print(DF_RAW.head())
# Out:
#             ImageID  Source LabelName  ...  XClick2Y  XClick3Y  XClick4Y
# 0  0000599864fd15b3  xclick       Bus  ...  0.512700  0.650047  0.457197
# 1  00006bdb1eb5cd74  xclick     Truck  ...  0.241855  0.352130  0.437343
# 2  00006bdb1eb5cd74  xclick     Truck  ...  0.398496  0.409774  0.295739
# 3  00010bf498b64bab  xclick       Bus  ...  0.493882  0.705228  0.521691
# 4  00013f14dd4e168f  xclick       Bus  ...  0.303940  0.999062  0.523452
#
# [5 rows x 21 columns]

# %% [markdown]
# Note that `XMin`, `XMax`, `YMin`, and `YMax` correspond to the ground truth of the bounding box of the image. Furthermore, LabelName provides the class of image.
#
# Define a class that returns the image and its corresponding class and ground truth along with the file path of the image:

# %%
class OpenImages(Dataset):

  def __init__(self, df, image_folder=IMAGE_ROOT):
    self.root = image_folder
    self.df = df
    self.unique_images = df["ImageID"].unique()

  def __len__(self):
    return len(self.unique_images)

  def __getitem__(self, idx):
    image_id = self.unique_images[idx]
    image_path = f"{self.root}/{image_id}.jpg"
    image = cv2.imread(image_path, 1)[..., ::-1]   # conver BGR to RGB
    h, w, _ = image.shape
    df = self.df.copy()
    df = df[df["ImageID"] == image_id]
    boxes = df["XMin,YMin,XMax,YMax".split(",")].values
    boxes = (boxes * np.array([w, h, w, h])).astype(np.uint16).tolist()
    classes = df["LabelName"].values.tolist()

    return image,boxes, classes, image_path

# %% [markdown]
# Inspect a sample image and its corresponding class and bounding box ground truth:

# %%
ds = OpenImages(df=DF_RAW)
img, bbs, clazz, _ = ds[9]
show(img, bbs=bbs, texts=clazz, sz=10)

# %%
ds = OpenImages(df=DF_RAW)
img, bbs, clazz, _ = ds[8]
show(img, bbs=bbs, texts=clazz, sz=10)

# %% [markdown]
# Define the extract_iou and extract_candidates functions:

# %%
def extract_candidates(img):
  img_label, regions = selectivesearch.selective_search(img, scale=200, min_size=100)
  img_area = np.prod(img.shape[:2])
  candidates = []

  for r in regions:
    if r["rect"] in candidates:
      continue
    if r["size"] < (0.05 * img_area):
      continue
    if r["size"] > (1 * img_area):
      continue
    x, y, w, h = r["rect"]
    candidates.append(list(r["rect"]))
  return candidates

# %%
def extract_iou(boxA, boxB, epsilon=1e-5):
  x1 = max(boxA[0], boxB[0])
  y1 = max(boxA[1], boxB[1])
  x2 = min(boxA[2], boxB[2])
  y2 = min(boxA[3], boxB[3])

  width = (x2 - x1)
  height = (y2 - y1)

  if (width < 0) or (height < 0):
    return 0.0
  
  area_overlap = width * height
  area_a = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])
  area_b = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])
  area_combined = area_a + area_b - area_overlap

  iou = area_overlap / (area_combined + epsilon)

  return iou

# %% [markdown]
# By now, we have defined all the functions necessary to prepare data and initialize data loaders.

# %% [markdown]
# ## Defining the region proposals extraction and IoU calculation functions

# %% [markdown]
# we will learn about creating the input and output values corresponding to our model. The input constitutes the candidates that are extracted using the selectivesearch method and the output constitutes the class corresponding to candidates and the offset of the candidate with respect to the bounding box it overlaps the most with if the candidate contains an object.
#
# **1.** Initialize empty lists to store file paths, ground truth bounding boxes , classes of objects, the delta offset of a bounding box with region proposals, region proposal locations, and the IoU of region proposals with ground truths:

# %%
FILE_PATHS, GTBBS, CLAZZ, DELTAS, ROIS, IOUS = [], [], [], [], [], []

# %% [markdown]
# **2.**Loop through the dataset and populate the lists initialized above:

# %%
N = 500
for idx, (im, bbs, labels, fpath) in enumerate(ds):
  if(idx == N):
    break
  H, W, _ = im.shape
  # Extract candidates from each image 
  candidates = extract_candidates(im)
  candidates = np.array([(x, y, x + w, y + h) for x, y, w, h in candidates])
  ious, rois, clss, deltas = [], [], [], []
  # Store the IoU of all candidates with respect to all ground truths for an image 
  ious = np.array([[extract_iou(candidate, _bb_) for candidate in candidates] for _bb_ in bbs]).T
  # Loop through each candidate
  for jx, candidate in enumerate(candidates):
    cx, cy, cX, cY = candidate
    # Extract the IoU corresponding to the candidate
    candidate_ious = ious[jx]
    # Find the index of a candidate that has the highest IoU and the corresponding ground truth 
    best_iou_at = np.argmax(candidate_ious)
    best_iou = candidate_ious[best_iou_at]
    best_bb = _x, _y, _X, _Y = bbs[best_iou_at]

    # If IoU (best_iou) is greater than a threshold (0.3), we assign the label of class corresponding to the candidate, and the background otherwise
    if best_iou > 0.3:
      clss.append(labels[best_iou_at])
    else:
      clss.append("background")
    # Fetch the offsets needed (delta) to transform the current proposal into the candidate that is the best region proposal-best_bb
    delta = np.array([_x - cx, _y - cy, _X - cX, _Y - cY]) / np.array([W, H, W, H])
    deltas.append(delta)
    rois.append(candidate / np.array([W, H, W, H]))
  FILE_PATHS.append(fpath)
  IOUS.append(ious)
  ROIS.append(rois)
  CLAZZ.append(clss)
  DELTAS.append(deltas)
  GTBBS.append(bbs)

# %% [markdown]
# Fetch the image path names and store all the information obtained, FPATHS, IOUS, ROIS, CLSS, DELTAS, and GTBBS, in a list of lists:

# %%
FILE_PATHS = [f"{IMAGE_ROOT}/{stem(f)}.jpg" for f in FILE_PATHS]
FILE_PATHS, GTBBS, CLAZZ, DELTAS, ROIS = [item for item in [FILE_PATHS, GTBBS, CLAZZ, DELTAS, ROIS]]

# %% [markdown]
# Note that, so far, classes are available as the name of the class. Now, we will convert them into their corresponding indices so that a background class has a class index of 0, a bus class has a class index of 1, and a truck class has a class index of 2.
#
# **3.** Assign indices to each class:

# %%
targets = pd.DataFrame(flatten(CLAZZ), columns=["label"])
label2target = {label: target for target, label in enumerate(targets["label"].unique())}
target2label = {target: label for label, target in label2target.items()}
background_class = label2target["background"]

# %% [markdown]
# So far, we have assigned a class to each region proposal and also created the other ground truth of the bounding box offset.

# %% [markdown]
# ## Creating the training data

# %% [markdown]
# We will prepare a dataset class based on the ground truth of region
# proposals that are obtained by the end of step 8 and create data loaders from it.
#
# Next, we will normalize each region proposal by resizing them to the same shape and scaling them.

# %%
# Define the function to normalize an image
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

# %%
# Define a function to preprocess the image
def preprocess_image(img):
  img = torch.tensor(img).permute(2, 0, 1)
  img = normalize(img)
  
  return img.to(device).float()

def decode(_y):
  _, preds = _y.max(-1)

  return preds

# %%
# Define the dataset using the preprocessed region proposals along with the ground truths
class FRCNNDataset(Dataset):

  def __init__(self, fpaths, rois, labels, deltas, gtbbs):
    self.fpaths = fpaths
    self.rois = rois
    self.labels = labels
    self.deltas = deltas
    self.gtbbs = gtbbs

  def __len__(self):
    return len(self.fpaths)

  def __getitem__(self, ix):
    """
    Fetch the image and crops as per the region proposals, along with the other
    ground truths related to class and the bounding box offset
    """
    fpath = str(self.fpaths[ix])
    image = cv2.imread(fpath, 1)[..., ::-1]
    gtbbs = self.gtbbs[ix]
    rois = self.rois[ix]
    labels = self.labels[ix]
    deltas = self.deltas[ix]
    
    assert len(rois) == len(labels) == len(deltas), f"{len(rois)}, {len(labels)}, {len(deltas)}"

    return image, rois, labels, deltas, gtbbs, fpath

  def collate_fn(self, batch):
    """
    performs the resizing and normalizing of an image of a crop
    """
    inputs, rois, rixs, labels, deltas = [], [], [], [], []
    for ix in range(len(batch)):
      image, image_rois, image_labels, image_deltas, image_gt_bbs, image_fpath = batch[ix]
      image = cv2.resize(image, (224, 224))
      inputs.extend(preprocess_image(image / 255.)[None])
      rois.extend(image_rois)
      rois.extend([ix] * len(image_rois))
      labels.extend([label2target[c] for c in image_labels])
      deltas.extend(image_deltas)
    inputs = torch.cat(inputs).to(device)
    rois = torch.Tensor(rois).float().to(device)
    rixs = torch.Tensor(rixs).float().to(device)
    labels = torch.Tensor(labels).long().to(device)
    deltas = torch.Tensor(deltas).float().to(device)

    return inputs, rois, rixs, labels, deltas

# %%
# Create the training and validation datasets and data loaders
n_train = 9 * len(FILE_PATHS) // 10
train_ds = FRCNNDataset(FILE_PATHS[:n_train], ROIS[:n_train], CLAZZ[:n_train], DELTAS[:n_train], GTBBS[:n_train])
test_ds = FRCNNDataset(FILE_PATHS[n_train:], ROIS[n_train:], CLAZZ[n_train:], DELTAS[n_train:], GTBBS[n_train:])

# %%
train_loader = DataLoader(train_ds, batch_size=2, collate_fn=train_ds.collate_fn, drop_last=True)
test_loader = DataLoader(test_ds, batch_size=2, collate_fn=test_ds.collate_fn, drop_last=True)

# %% [markdown]
# ## R-CNN network architecture

# %% [markdown]
# Now that we have prepared the data, we will learn about building a
# model that can predict both the class of region proposal and the offset corresponding to it in order to draw a tight bounding box around the object in the image.

# %%
# Define the FRCNN network module
class FRCNN(nn.Module):

  def __init__(self):
    super().__init__()
    # Load the pretrained model and freeze the parameters
    rawnet = torchvision.models.vgg16_bn(pretrained=True)
    for param in rawnet.features.parameters():
      param.requires_grad = True
    # Extract features until the last layer
    self.seq = nn.Sequential(*list(rawnet.features.children())[:-1])
    # Specify that RoIPool is to extract a 7 x 7 output
    self.roipool = RoIPool(7, spatial_scale=14 / 224)

    # Define the output heads – cls_score and bbox
    feature_dim = 512 * 7 * 7
    self.cls_score = nn.Linear(feature_dim, len(label2target))
    self.bbox = nn.Sequential(
        nn.Linear(feature_dim, 512),
        nn.ReLU(),
        nn.Linear(512, 4),
        nn.Tanh()
    )

    # Define the loss functions
    self.cross_entropy_loss = nn.CrossEntropyLoss()
    self.loss_l1 = nn.L1Loss()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# HBox(children=(FloatProgress(value=0.0, max=553433881.0), HTML(value='')))
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential()
# )

# %%
# 2. Define the RCNN network module
class RCNN(nn.Module):

  def __init__(self):
    super().__init__()
    feature_dim = 25088
    self.backbone = vgg_backbone 
    self.clazz_score = nn.Linear(feature_dim, len(target2label))
    self.bbox = nn.Sequential(
        nn.Linear(feature_dim, 512),
        nn.ReLU(),
        nn.Linear(512, 4),
        nn.Tanh()
    )
    self.cross_entropy_loss = nn.CrossEntropyLoss()
    self.l1_loss = nn.L1Loss()

  def forward(self, inputs):
    """
    Define the feed-forward method where we pass the image through a
    VGG backbone (self.backbone) to fetch features (features), which are
    further passed through the methods corresponding to classification
    and bounding box regression to fetch the probabilities across classes
    (clazz_score) and the bounding box offsets (bbox):
    """
    features = self.backbone(inputs)
    clazz_score = self.clazz_score(features)
    bbox = self.bbox(features)

    return clazz_score, bbox

  def calculate_loss(self, probs, _deltas, labels, deltas):
    detection_loss = self.cross_entropy_loss(probs, labels)
    ixs, = torch.where(labels != 0)
    _deltas = _deltas[ixs]
    deltas = deltas[ixs]
    self.lmb = 10.0
    if len(ixs) > 0:
      regression_loss = self.l1_loss(_deltas, deltas)
      return detection_loss + self.lmb * regression_loss, detection_loss.detach(), regression_loss.detach()
    else:
      regression_loss = 0
      return detection_loss + self.lmb * regression_loss, detection_loss.detach(), regression_loss

# %%
def train_batch(inputs, model, optimizer, criterion):
  inputs, clazz, deltas = inputs
  model.train()
  optimizer.zero_grad()
  _clazz, _deltas = model(inputs)
  loss, loc_loss, regr_loss = criterion(_clazz, _deltas, clazz, deltas)
  accs = clazz == decode(_clazz)
  loss.backward()
  optimizer.step()

  return loss.detach(), loc_loss, regr_loss, accs.cpu().numpy()

# %%
@torch.no_grad()
def validate_batch(inputs, model, criterion):
  inputs, clazz, deltas = inputs
  with torch.no_grad():
    model.eval()
    _clazz, _deltas = model(inputs)
    loss, loc_loss, regr_loss = criterion(_clazz, _deltas, clazz, deltas)
    _, _clazz = _clazz.max(-1)
    accs = clazz == _clazz
  return _clazz, _deltas, loss.detach(), loc_loss, regr_loss, accs.cpu().numpy()

# %% [markdown]
# Now, let's create an object of the model, fetch the loss criterion, and then
# define the optimizer and the number of epochs:

# %%
rcnn = RCNN().to(device)
criterion = rcnn.calculate_loss
optimizer = optim.SGD(rcnn.parameters(), lr=1e-3)
n_epochs = 5
log = Report(n_epochs)

# %% [markdown]
# We now train the model over increasing epochs.

# %%
for epoch in range(n_epochs):
  _n = len(train_loader)
  for ix, inputs in enumerate(train_loader):
    print(ix)
    #print(inputs.size())
    loss, loc_loss, regr_loss, accs = train_batch(inputs, rcnn, optimizer, criterion)
    pos = (epoch + (ix + 1) / _n)
    log.record(pos, trn_loss=loss.item(), trn_loc_loss=loc_loss, trn_regr_loss=regr_loss, trn_acc=accs.mean(), end="\r")
  
  _n = len(test_loader)
  for ix, inputs in enumerate(test_loader):
    _clazz, _deltas, loss, loc_loss, regr_loss, accs = validate_batch(inputs, rcnn, criterion)
    pos = (epoch + (ix + 1) / _n)
    log.record(pos, val_loss=loss.item(), val_loc_loss=loc_loss, val_regr_loss=regr_loss, val_acc=accs.mean(), end="\r")

# Plotting training and validation metrics
log.plot_epochs("trn_loss,val_loss".split(","))
# Out:
# 0
# EPOCH: 0.004	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1.61s - 1806.73s remaining)1
# EPOCH: 0.009	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(3.07s - 1722.75s remaining)2
# EPOCH: 0.013	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(4.21s - 1572.83s remaining)3
# EPOCH: 0.018	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(5.58s - 1564.64s remaining)4
# EPOCH: 0.022	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(6.82s - 1526.61s remaining)5
# EPOCH: 0.027	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(8.04s - 1498.93s remaining)6
# EPOCH: 0.031	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(9.32s - 1488.41s remaining)7
# EPOCH: 0.036	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(10.38s - 1449.05s remaining)8
# EPOCH: 0.040	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(11.47s - 1422.29s remaining)9
# EPOCH: 0.044	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(12.51s - 1395.12s remaining)10
# EPOCH: 0.049	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(13.71s - 1388.38s remaining)11
# EPOCH: 0.053	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(14.82s - 1374.98s remaining)12
# EPOCH: 0.058	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(16.27s - 1391.46s remaining)13
# EPOCH: 0.062	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(17.34s - 1376.04s remaining)14
# EPOCH: 0.067	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(18.44s - 1364.75s remaining)15
# EPOCH: 0.071	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(19.73s - 1367.27s remaining)16
# EPOCH: 0.076	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(21.10s - 1375.51s remaining)17
# EPOCH: 0.080	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(22.46s - 1381.45s remaining)18
# EPOCH: 0.084	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(23.54s - 1370.47s remaining)19
# EPOCH: 0.089	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(24.63s - 1360.84s remaining)20
# EPOCH: 0.093	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(26.03s - 1368.63s remaining)21
# EPOCH: 0.098	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(27.55s - 1381.14s remaining)22
# EPOCH: 0.102	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(28.93s - 1386.05s remaining)23
# EPOCH: 0.107	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(29.98s - 1375.34s remaining)24
# EPOCH: 0.111	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(31.07s - 1367.02s remaining)25
# EPOCH: 0.116	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(32.28s - 1364.42s remaining)26
# EPOCH: 0.120	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(33.34s - 1355.70s remaining)27
# EPOCH: 0.124	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(34.36s - 1346.24s remaining)28
# EPOCH: 0.129	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(35.28s - 1333.52s remaining)29
# EPOCH: 0.133	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(36.38s - 1327.87s remaining)30
# EPOCH: 0.138	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(37.26s - 1314.95s remaining)31
# EPOCH: 0.142	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(38.58s - 1317.61s remaining)32
# EPOCH: 0.147	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	
trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(165.54s - 1224.23s remaining)134
# EPOCH: 0.600	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(166.92s - 1224.08s remaining)135
# EPOCH: 0.604	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(168.43s - 1224.84s remaining)136
# EPOCH: 0.609	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(169.64s - 1223.36s remaining)137
# EPOCH: 0.613	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(171.10s - 1223.75s remaining)138
# EPOCH: 0.618	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(172.47s - 1223.40s remaining)139
# EPOCH: 0.622	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(174.08s - 1224.81s remaining)140
# EPOCH: 0.627	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(175.10s - 1221.96s remaining)141
# EPOCH: 0.631	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(176.49s - 1221.74s remaining)142
# EPOCH: 0.636	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(178.00s - 1222.37s remaining)143
# EPOCH: 0.640	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(179.31s - 1221.55s remaining)144
# EPOCH: 0.644	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(180.77s - 1221.77s remaining)145
# EPOCH: 0.649	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(181.92s - 1219.85s remaining)146
# EPOCH: 0.653	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(183.20s - 1218.84s remaining)147
# EPOCH: 0.658	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(184.49s - 1217.87s remaining)148
# EPOCH: 0.662	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(186.08s - 1218.88s remaining)149
# EPOCH: 0.667	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(187.21s - 1216.85s remaining)150
# EPOCH: 0.671	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(188.50s - 1215.88s remaining)151
# EPOCH: 0.676	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(189.70s - 1214.34s remaining)152
# EPOCH: 0.680	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(190.80s - 1212.14s remaining)153
# EPOCH: 0.684	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(192.13s - 1211.43s remaining)154
# EPOCH: 0.689	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(193.31s - 1209.72s remaining)155
# EPOCH: 0.693	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(194.66s - 1209.12s remaining)156
# EPOCH: 0.698	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(195.83s - 1207.39s remaining)157
# EPOCH: 0.702	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(197.12s - 1206.40s remaining)158
# EPOCH: 0.707	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(198.45s - 1205.67s remaining)159
# EPOCH: 0.711	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(199.83s - 1205.20s remaining)160
# EPOCH: 0.716	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(201.02s - 1203.61s remaining)161
# EPOCH: 0.720	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(202.00s - 1200.79s remaining)162
# EPOCH: 0.724	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(203.17s - 1199.07s remaining)163
# EPOCH: 0.729	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(204.34s - 1197.40s remaining)164
# EPOCH: 0.733	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(205.54s - 1195.85s remaining)165
# EPOCH: 0.738	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(207.29s - 1197.52s remaining)166
# EPOCH: 0.742	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(208.47s - 1195.91s remaining)167
# EPOCH: 0.747	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(209.88s - 1195.56s remaining)168
# EPOCH: 0.751	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(211.27s - 1195.12s remaining)169
# EPOCH: 0.756	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(212.38s - 1193.09s remaining)170
# EPOCH: 0.760	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(213.89s - 1193.29s remaining)171
# EPOCH: 0.764	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(215.20s - 1192.35s remaining)172
# EPOCH: 0.769	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(216.43s - 1190.96s remaining)173
# EPOCH: 0.773	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(217.58s - 1189.21s remaining)174
# EPOCH: 0.778	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(219.21s - 1189.99s remaining)175
# EPOCH: 0.782	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(220.72s - 1190.13s remaining)176
# EPOCH: 0.787	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(221.92s - 1188.61s remaining)177
# EPOCH: 0.791	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(223.11s - 1186.97s remaining)178
# EPOCH: 0.796	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(224.64s - 1187.22s remaining)179
# EPOCH: 0.800	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(226.00s - 1186.51s remaining)180
# EPOCH: 0.804	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(227.17s - 1184.79s remaining)181
# EPOCH: 0.809	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(228.54s - 1184.13s remaining)182
# EPOCH: 0.813	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(229.64s - 1182.10s remaining)183
# EPOCH: 0.818	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(231.03s - 1181.54s remaining)184
# EPOCH: 0.822	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	
trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(311.11s - 1184.62s remaining)9
# EPOCH: 1.044	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(312.25s - 1182.55s remaining)10
# EPOCH: 1.049	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(313.56s - 1181.17s remaining)11
# EPOCH: 1.053	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(314.77s - 1179.38s remaining)12
# EPOCH: 1.058	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(316.31s - 1178.84s remaining)13
# EPOCH: 1.062	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(317.47s - 1176.90s remaining)14
# EPOCH: 1.067	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(318.66s - 1175.07s remaining)15
# EPOCH: 1.071	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(320.06s - 1173.98s remaining)16
# EPOCH: 1.076	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(321.55s - 1173.25s remaining)17
# EPOCH: 1.080	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(323.04s - 1172.51s remaining)18
# EPOCH: 1.084	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(324.20s - 1170.59s remaining)19
# EPOCH: 1.089	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(325.38s - 1168.73s remaining)20
# EPOCH: 1.093	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(326.90s - 1168.05s remaining)21
# EPOCH: 1.098	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(328.27s - 1166.89s remaining)22
# EPOCH: 1.102	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(329.79s - 1166.24s remaining)23
# EPOCH: 1.107	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(330.93s - 1164.22s remaining)24
# EPOCH: 1.111	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(332.10s - 1162.35s remaining)25
# EPOCH: 1.116	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(333.41s - 1160.97s remaining)26
# EPOCH: 1.120	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(334.57s - 1159.04s remaining)27
# EPOCH: 1.124	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(335.69s - 1156.99s remaining)28
# EPOCH: 1.129	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(336.67s - 1154.49s remaining)29
# EPOCH: 1.133	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(337.86s - 1152.70s remaining)30
# EPOCH: 1.138	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(338.81s - 1150.09s remaining)31
# EPOCH: 1.142	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(340.19s - 1148.98s remaining)32
# EPOCH: 1.147	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(341.40s - 1147.27s remaining)33
# EPOCH: 1.151	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(342.74s - 1145.99s remaining)34
# EPOCH: 1.156	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(343.74s - 1143.60s remaining)35
# EPOCH: 1.160	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(345.28s - 1143.00s remaining)36
# EPOCH: 1.164	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(346.63s - 1141.76s remaining)37
# EPOCH: 1.169	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(348.19s - 1141.21s remaining)38
# EPOCH: 1.173	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(349.38s - 1139.46s remaining)39
# EPOCH: 1.178	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(350.71s - 1138.15s remaining)40
# EPOCH: 1.182	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(351.88s - 1136.34s remaining)41
# EPOCH: 1.187	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(353.09s - 1134.66s remaining)42
# EPOCH: 1.191	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(354.28s - 1132.91s remaining)43
# EPOCH: 1.196	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(355.50s - 1131.25s remaining)44
# EPOCH: 1.200	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(356.45s - 1128.75s remaining)45
# EPOCH: 1.204	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(357.87s - 1127.75s remaining)46
# EPOCH: 1.209	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(359.30s - 1126.77s remaining)47
# EPOCH: 1.213	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(360.61s - 1125.42s remaining)48
# EPOCH: 1.218	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(361.82s - 1123.76s remaining)49
# EPOCH: 1.222	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(362.98s - 1121.94s remaining)50
# EPOCH: 1.227	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(364.00s - 1119.69s remaining)51
# EPOCH: 1.231	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(365.41s - 1118.66s remaining)52
# EPOCH: 1.236	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(366.92s - 1117.93s remaining)53
# EPOCH: 1.240	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(368.12s - 1116.23s remaining)54
# EPOCH: 1.244	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(369.55s - 1115.24s remaining)55
# EPOCH: 1.249	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(370.74s - 1113.53s remaining)56
# EPOCH: 1.253	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(372.28s - 1112.88s remaining)57
# EPOCH: 1.258	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(373.92s - 1112.51s remaining)58
# EPOCH: 1.262	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(375.05s - 1110.62s remaining)59
# EPOCH: 1.267	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(376.25s - 1108.94s remaining)60
# EPOCH: 1.271	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(377.94s - 1108.72s remaining)61
# EPOCH: 1.276	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(379.17s - 1107.13s remaining)62
# EPOCH: 1.280	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(380.39s - 1105.52s remaining)63
# EPOCH: 1.284	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(381.53s - 1103.68s remaining)64
# EPOCH: 1.289	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(382.76s - 1102.09s remaining)65
# EPOCH: 1.293	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(383.78s - 1099.90s remaining)66
# EPOCH: 1.298	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(385.10s - 1098.59s remaining)67
# EPOCH: 1.302	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(386.52s - 1097.55s remaining)68
# EPOCH: 1.307	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(387.86s - 1096.29s remaining)69
# EPOCH: 1.311	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(389.09s - 1094.74s remaining)70
# EPOCH: 1.316	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(390.52s - 1093.73s remaining)71
# EPOCH: 1.320	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(391.76s - 1092.19s remaining)72
# EPOCH: 1.324	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(393.01s - 1090.67s remaining)73
# EPOCH: 1.329	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(394.33s - 1089.36s remaining)74
# EPOCH: 1.333	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(395.50s - 1087.63s remaining)75
# EPOCH: 1.338	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(397.17s - 1087.27s remaining)76
# EPOCH: 1.342	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(398.40s - 1085.69s remaining)77
# EPOCH: 1.347	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(399.63s - 1084.15s remaining)78
# EPOCH: 1.351	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(400.85s - 1082.55s remaining)79
# EPOCH: 1.356	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(402.25s - 1081.46s remaining)80
# EPOCH: 1.360	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(403.94s - 1081.14s remaining)81
# EPOCH: 1.364	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(405.29s - 1079.90s remaining)82
# EPOCH: 1.369	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(406.50s - 1078.28s remaining)83
# EPOCH: 1.373	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(408.05s - 1077.56s remaining)84
# EPOCH: 1.378	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(409.20s - 1075.80s remaining)85
# EPOCH: 1.382	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(410.54s - 1074.53s remaining)86
# EPOCH: 1.387	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(411.73s - 1072.87s remaining)87
# EPOCH: 1.391	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(412.73s - 1070.73s remaining)88
# EPOCH: 1.396	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(414.36s - 1070.21s remaining)89
# EPOCH: 1.400	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(415.74s - 1069.05s remaining)90
# EPOCH: 1.404	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(416.73s - 1066.89s remaining)91
# EPOCH: 1.409	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(417.94s - 1065.30s remaining)92
# EPOCH: 1.413	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(419.44s - 1064.42s remaining)93
# EPOCH: 1.418	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(420.69s - 1062.94s remaining)94
# EPOCH: 1.422	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(422.34s - 1062.46s remaining)95
# EPOCH: 1.427	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(423.46s - 1060.62s remaining)96
# EPOCH: 1.431	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(424.65s - 1058.98s remaining)97
# EPOCH: 1.436	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(425.83s - 1057.32s remaining)98
# EPOCH: 1.440	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(427.05s - 1055.75s remaining)99
# EPOCH: 1.444	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(428.26s - 1054.17s remaining)100
# EPOCH: 1.449	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(429.27s - 1052.10s remaining)101
# EPOCH: 1.453	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(430.61s - 1050.84s remaining)102
# EPOCH: 1.458	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(431.79s - 1049.19s remaining)103
# EPOCH: 1.462	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(433.00s - 1047.62s remaining)104
# EPOCH: 1.467	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(434.23s - 1046.10s remaining)105
# EPOCH: 1.471	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(435.78s - 1045.35s remaining)106
# EPOCH: 1.476	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(437.33s - 1044.59s remaining)107
# EPOCH: 1.480	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(438.71s - 1043.41s remaining)108
# EPOCH: 1.484	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(440.40s - 1042.98s remaining)109
# EPOCH: 1.489	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(441.83s - 1041.92s remaining)110
# EPOCH: 1.493	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(443.21s - 1040.76s remaining)111
# EPOCH: 1.498	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(444.98s - 1040.48s remaining)112
# EPOCH: 1.502	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(446.36s - 1039.30s remaining)113
# EPOCH: 1.507	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(448.07s - 1038.89s remaining)114
# EPOCH: 1.511	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(449.25s - 1037.24s remaining)115
# EPOCH: 1.516	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(450.26s - 1035.20s remaining)116
# EPOCH: 1.520	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(451.19s - 1033.00s remaining)117
# EPOCH: 1.524	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(452.43s - 1031.48s remaining)118
# EPOCH: 1.529	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(453.64s - 1029.93s remaining)119
# EPOCH: 1.533	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(455.07s - 1028.86s remaining)120
# EPOCH: 1.538	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(456.27s - 1027.26s remaining)121
# EPOCH: 1.542	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(457.46s - 1025.66s remaining)122
# EPOCH: 1.547	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(458.88s - 1024.57s remaining)123
# EPOCH: 1.551	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(460.41s - 1023.71s remaining)124
# EPOCH: 1.556	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(461.79s - 1022.52s remaining)125
# EPOCH: 1.560	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(463.04s - 1021.05s remaining)126
# EPOCH: 1.564	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(464.01s - 1018.97s remaining)127
# EPOCH: 1.569	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(465.26s - 1017.52s remaining)128
# EPOCH: 1.573	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(466.62s - 1016.28s remaining)129
# EPOCH: 1.578	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(467.95s - 1015.00s remaining)130
# EPOCH: 1.582	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(469.18s - 1013.49s remaining)131
# EPOCH: 1.587	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(470.87s - 1012.96s remaining)132
# EPOCH: 1.591	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(472.58s - 1012.47s remaining)133
# EPOCH: 1.596	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(473.80s - 1010.96s remaining)134
# EPOCH: 1.600	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(475.23s - 1009.86s remaining)135
# EPOCH: 1.604	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(476.78s - 1009.04s remaining)136
# EPOCH: 1.609	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(478.02s - 1007.55s remaining)137
# EPOCH: 1.613	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(479.53s - 1006.62s remaining)138
# EPOCH: 1.618	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(480.92s - 1005.43s remaining)139
# EPOCH: 1.622	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(482.57s - 1004.80s remaining)140
# EPOCH: 1.627	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(483.60s - 1002.87s remaining)141
# EPOCH: 1.631	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(485.03s - 1001.78s remaining)142
# EPOCH: 1.636	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(486.56s - 1000.88s remaining)143
# EPOCH: 1.640	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(487.90s - 999.60s remaining)144
# EPOCH: 1.644	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(489.40s - 998.65s remaining)145
# EPOCH: 1.649	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(490.59s - 997.04s remaining)146
# EPOCH: 1.653	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(491.89s - 995.68s remaining)147
# EPOCH: 1.658	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(493.22s - 994.37s remaining)148
# EPOCH: 1.662	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(494.85s - 993.67s remaining)149
# EPOCH: 1.667	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(496.01s - 992.02s remaining)150
# EPOCH: 1.671	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(497.35s - 990.73s remaining)151
# EPOCH: 1.676	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(498.59s - 989.24s remaining)152
# EPOCH: 1.680	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(499.72s - 987.55s remaining)153
# EPOCH: 1.684	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(501.09s - 986.31s remaining)154
# EPOCH: 1.689	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(502.29s - 984.75s remaining)155
# EPOCH: 1.693	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(503.68s - 983.56s remaining)156
# EPOCH: 1.698	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(504.89s - 982.02s remaining)157
# EPOCH: 1.702	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(506.21s - 980.70s remaining)158
# EPOCH: 1.707	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(507.59s - 979.50s remaining)159
# EPOCH: 1.711	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(509.00s - 978.34s remaining)160
# EPOCH: 1.716	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(510.22s - 976.82s remaining)161
# EPOCH: 1.720	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	
trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1473.52s - 61.40s remaining)180
# EPOCH: 4.804	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1474.72s - 60.03s remaining)181
# EPOCH: 4.809	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1476.13s - 58.66s remaining)182
# EPOCH: 4.813	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1477.25s - 57.29s remaining)183
# EPOCH: 4.818	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1478.66s - 55.93s remaining)184
# EPOCH: 4.822	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1480.08s - 54.57s remaining)185
# EPOCH: 4.827	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1481.74s - 53.21s remaining)186
# EPOCH: 4.831	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1482.94s - 51.84s remaining)187
# EPOCH: 4.836	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1484.18s - 50.47s remaining)188
# EPOCH: 4.840	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1485.54s - 49.11s remaining)189
# EPOCH: 4.844	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1486.79s - 47.74s remaining)190
# EPOCH: 4.849	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1488.20s - 46.38s remaining)191
# EPOCH: 4.853	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1489.53s - 45.01s remaining)192
# EPOCH: 4.858	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1490.78s - 43.65s remaining)193
# EPOCH: 4.862	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1492.01s - 42.28s remaining)194
# EPOCH: 4.867	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1493.20s - 40.91s remaining)195
# EPOCH: 4.871	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1494.43s - 39.54s remaining)196
# EPOCH: 4.876	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1495.68s - 38.18s remaining)197
# EPOCH: 4.880	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1497.05s - 36.81s remaining)198
# EPOCH: 4.884	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1498.60s - 35.45s remaining)199
# EPOCH: 4.889	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1499.83s - 34.09s remaining)200
# EPOCH: 4.893	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1501.52s - 32.73s remaining)201
# EPOCH: 4.898	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1502.52s - 31.36s remaining)202
# EPOCH: 4.902	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1503.72s - 29.99s remaining)203
# EPOCH: 4.907	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1505.16s - 28.63s remaining)204
# EPOCH: 4.911	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1506.62s - 27.27s remaining)205
# EPOCH: 4.916	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1507.82s - 25.90s remaining)206
# EPOCH: 4.920	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1509.18s - 24.54s remaining)207
# EPOCH: 4.924	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1510.11s - 23.17s remaining)208
# EPOCH: 4.929	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1511.54s - 21.81s remaining)209
# EPOCH: 4.933	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1512.79s - 20.44s remaining)210
# EPOCH: 4.938	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1514.36s - 19.08s remaining)211
# EPOCH: 4.942	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1515.59s - 17.72s remaining)212
# EPOCH: 4.947	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1516.77s - 16.35s remaining)213
# EPOCH: 4.951	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1517.97s - 14.99s remaining)214
# EPOCH: 4.956	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1519.49s - 13.63s remaining)215
# EPOCH: 4.960	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1521.28s - 12.27s remaining)216
# EPOCH: 4.964	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1522.49s - 10.90s remaining)217
# EPOCH: 4.969	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1523.37s - 9.54s remaining)218
# EPOCH: 4.973	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1524.58s - 8.17s remaining)219
# EPOCH: 4.978	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1525.94s - 6.81s remaining)220
# EPOCH: 4.982	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1527.30s - 5.45s remaining)221
# EPOCH: 4.987	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1529.11s - 4.09s remaining)222
# EPOCH: 4.991	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1530.50s - 2.73s remaining)223
# EPOCH: 4.996	trn_loss: 0.000	trn_loc_loss: 0.000	trn_regr_loss: 0.000	trn_acc: 1.000	(1531.94s - 1.36s remaining)224
# EPOCH: 4.960	val_loss: 0.000	val_loc_loss: 0.000	val_regr_loss: 0.000	val_acc: 1.000	(1547.61s - 12.48s remaining)
#   0%|          | 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 6/6 [00:00<00:00, 603.08it/s]
# EPOCH: 5.000	val_loss: 0.000	val_loc_loss: 0.000	val_regr_loss: 0.000	val_acc: 1.000	(1548.18s - 0.00s remaining)

# %% [markdown]
# ### Predict on a new image

# %% [markdown]
# we will leverage the model trained so far to predict and draw
# bounding boxes around objects and the corresponding class of object within the
# predicted bounding box on new images. The strategy we adopt is as follows:
#
# 1. Extract region proposals from the new image.
# 2. Resize and normalize each crop.
# 3. Feed-forward the processed crops to make predictions of class and the
# offsets.
# 4. Perform non-max suppression to fetch only those boxes that have the
# highest confidence of containing an object.
#
# We execute the preceding strategy through a function that takes an image as input and a ground truth bounding box (this is used only so that we compare the ground truth and the predicted bounding box).

# %%
def test_predictions(filename, show_output=True):
  # Read the image and extract candidates
  img = np.array(cv2.imread(filename, 1)[..., ::-1])
  candidates = extract_candidates(img)
  candidates = [(x, y, x + w, y + h) for x, y, w, h in candidates]

  # Loop through the candidates to resize and preprocess the image
  inputs = []
  for candidate in candidates:
    x, y, X, Y = candidate
    crop = cv2.resize(img[y:Y, x:X], (224, 224))
    inputs.append(preprocess_image(crop / 255.)[None])
  inputs = torch.cat(inputs).to(device)

  # Predict the class and offset
  with torch.no_grad():
    rcnn.eval()
    probs, deltas = rcnn(inputs)
    probs = torch.nn.functional.softmax(probs, -1)
    confs, clss = torch.max(probs, -1)
  
  # Extract the candidates that do not belong to the background class and sum up the candidates with the predicted bounding box offset values
  candidates = np.array(candidates)
  confs, clss, probs, deltas = [tensor.detach().cpu().numpy() for tensor in [confs, clss, probs, deltas]]

  """
  Use non-max suppression nms to eliminate near-duplicate bounding
  boxes (pairs of boxes that have an IoU greater than 0.05 are considered
  duplicates in this case). Among the duplicated boxes, we pick that box
  with the highest confidence and discard the rest:
  """
  ixs = clss != background_class
  confs, clss, probs, deltas, candidates = [tensor[ixs] for tensor in [confs, clss, probs, deltas, candidates]]
  bbs = (candidates + deltas).astype(np.uint16)
  ixs = nms(torch.tensor(bbs.astype(np.float32)), torch.tensor(confs), 0.05)
  confs, clss, probs, deltas, candidates, bbs = [tensor[ixs] for tensor in [confs, clss, probs, deltas, candidates, bbs]]
  if len(ixs) == 1:
    confs, clss, probs, deltas, candidates, bbs = [tensor(None) for tensor in [confs, clss, probs, deltas, candidates, bbs]]

  # Fetch the bounding box with the highest confidence
  if len(confs) == 0 and not show_output:
    return (0, 0, 224, 224), "background", 0
  if len(confs) > 0:
    best_pred = np.argmax(confs)
    best_conf = np.max(confs)
    best_bb = bbs[best_pred]
    x, y, X, Y = best_bb

  # Plot the image along with the predicted bounding box
  _, ax = plt.subplots(1, 2, figsize=(20, 10))
  ax[0].grid(False)
  ax[0].set_title('Original image')
  if len(confs) == 0:
      ax[1].imshow(img)
      ax[1].set_title('No objects')
      plt.show()
      return
  ax[1].set_title(target2label[clss[best_pred]])
  show(img, bbs=bbs.tolist(), texts=[target2label[c] for c in clss.tolist()], ax=ax[1], title='predicted bounding box and class')
  plt.show()

  return (x, y, X, Y), target2label[clss[best_pred]], best_conf

# %%
image, crops, bbs, labels, deltas, gtbbs, fpath = test_ds[7]
test_predictions(fpath)

# %% [markdown]
# All of this time is consumed in generating region proposals, resizing each region proposal, passing them through a VGG backbone, and generating predictions using the defined model. Most of the time, however, is spent in passing each proposal through a VGG backbone.
